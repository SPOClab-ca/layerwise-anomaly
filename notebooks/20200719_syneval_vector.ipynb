# %% [markdown]
# # LM_syneval
# Use the syntactic pairs from [Marvin and Linzen, 2018](https://github.com/BeckyMarvin/LM_syneval). Compare their diff vector results to the Time Vector results.
# - Compare the magnitude of variance using sns.distplot
# - Compare the orthogonality using cosine similarity

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import numpy as np
import os, sys, time
import pandas as pd
import pickle
import scipy
import seaborn as sns
import sklearn
from sklearn.decomposition import PCA
import spacy
import torch

from utils import timed_func

# %%
import transformers
from transformers import BertModel, BertTokenizer
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
bert_model = BertModel.from_pretrained('bert-base-cased', output_hidden_states=False)
nlp = spacy.load("en_core_web_md")

def evaluate_contextual_diff(pair):
    source, target = pair[0], pair[1]
    src_ids = torch.tensor(bert_tokenizer.encode(source)).unsqueeze(0)
    src_vec = bert_model(src_ids)[0].mean(dim=1)[0]  # (768,) torch.tensor
    
    tgt_ids = torch.tensor(bert_tokenizer.encode(target)).unsqueeze(0)
    tgt_vec = bert_model(tgt_ids)[0].mean(dim=1)[0]
    
    d_emb = len(src_vec)  # 768
    diff = src_vec - tgt_vec
    return diff  # 768-dimensional torch.tensor

# %% [markdown]
# ## Preprocess syneval pairs
# For each syneval_task, there are >=2 keys, each pertaning to a category. A category contains list of N sentences, but only the first sentence is syntactically correct.

# %%
lm_syneval_dir = "../data/LM_syneval/data"

def get_syneval_data():
    syneval_names = [
        "vp_coord", "subj_rel", "simple_reflexives", 
        "simple_npi_inanim", "simple_npi_anim",
        "simple_agrmt", "sent_comp", "reflexives_across",
        "reflexive_sent_comp", "prep_inanim", "prep_anim",
        "obj_rel_within_inanim", "obj_rel_within_anim",
        "obj_rel_no_comp_within_inanim", "obj_rel_no_comp_within_anim",
        "obj_rel_no_comp_across_inanim", "obj_rel_no_comp_across_anim",
        "obj_rel_across_inanim", "obj_rel_across_anim",
        "npi_across_inanim", "npi_across_anim",
        "long_vp_coord"
    ]

    syneval_data = {}
    eda_data = {
        "name_": [], "keys_": [], "n_item": [], "sample_k0": [], "sample_k1": []
    }
    for name in syneval_names:
        with open(os.path.join(lm_syneval_dir, "templates/{}.pickle".format(name)), "rb") as f:
            data = pickle.load(f)
            syneval_data[name] = data
            
            eda_data["name_"].append(name)
            
            keys = list(data.keys())
            eda_data["keys_"].append(keys)

            n_item = None
            for k in data.keys():
                if n_item is None:
                    n_item = len(data[k])
                else:
                    if len(data[k]) != n_item:
                        n_item = -1  # This means the classes have different nums of items
            eda_data["n_item"].append(n_item)

            eda_data["sample_k0"].append(data[keys[0]][0])
            eda_data["sample_k1"].append(data[keys[1]][0])
    return syneval_data, pd.DataFrame(eda_data)

syneval_data, eda_data = get_syneval_data()
eda_data
# Out:
#                             name_  \
# 0                        vp_coord
# 1                        subj_rel
# 2               simple_reflexives
# 3               simple_npi_inanim
# 4                 simple_npi_anim
# 5                    simple_agrmt
# 6                       sent_comp
# 7               reflexives_across
# 8             reflexive_sent_comp
# 9                     prep_inanim
# 10                      prep_anim
# 11          obj_rel_within_inanim
# 12            obj_rel_within_anim
# 13  obj_rel_no_comp_within_inanim
# 14    obj_rel_no_comp_within_anim
# 15  obj_rel_no_comp_across_inanim
# 16    obj_rel_no_comp_across_anim
# 17          obj_rel_across_inanim
# 18            obj_rel_across_anim
# 19              npi_across_inanim
# 20                npi_across_anim
# 21                  long_vp_coord
#
#                                                 keys_  n_item  \
# 0                      [sing_MS_MV_MV, plur_MS_MV_MV]     420
# 1   [sing_MS_EV_MV_sing_ES, sing_MS_EV_MV_plur_ES,...    2800
# 2                      [sing_MS_ANPHR, plur_MS_ANPHR]     140
# 3                                      [past, future]      72
# 4                                      [past, future]      60
# 5                            [sing_MS_MV, plur_MS_MV]      70
# 6   [sing_MS_MV_sing_BS, sing_MS_MV_plur_BS, plur_...     420
# 7   [sing_MS_ANPHR_sing_ES_EV, sing_MS_ANPHR_plur_...    5600
# 8   [sing_MS_ANPHR_sing_BS, sing_MS_ANPHR_plur_BS,...     840
# 9   [sing_IS_IV_sing_ES, sing_IS_IV_plur_ES, plur_...    1260
# 10  [sing_MS_MV_sing_ES, sing_MS_MV_plur_ES, plur_...    4200
# 11  [sing_ES_EV_sing_IS_IV, sing_ES_EV_plur_IS_IV,...    2520
# 12  [sing_ES_EV_sing_MS_MV, sing_ES_EV_plur_MS_MV,...    2800
# 13  [sing_ES_EV_sing_IS_IV, sing_ES_EV_plur_IS_IV,...    2520
# 14  [sing_ES_EV_sing_MS_MV, sing_ES_EV_plur_MS_MV,...    2800
# 15  [sing_IS_IV_sing_ES_EV, sing_IS_IV_plur_ES_EV,...    2520
# 16  [sing_MS_MV_sing_ES_EV, sing_MS_MV_plur_ES_EV,...    2800
# 17  [sing_IS_IV_sing_ES_EV, sing_IS_IV_plur_ES_EV,...    2520
# 18  [sing_MS_MV_sing_ES_EV, sing_MS_MV_plur_ES_EV,...    2800
# 19                                     [past, future]    2880
# 20                                     [past, future]    2400
# 21                 [sing_MS_LMV_LMV, plur_MS_LMV_LMV]     200
#
#                                             sample_k0  \
# 0   (the author laughs and swims, the author laugh...
# 1   (the author that likes the guard laughs, the a...
# 2   (the author hurt himself, the author hurt them...
# 3   (no movies have ever been seen, the movies hav...
# 4   (no authors have ever been popular, the author...
# 5               (the author laughs, the author laugh)
# 6   (the mechanic said the author laughs, the mech...
# 7   (the author that the guard likes hurt himself,...
# 8   (the mechanic said the author hurt himself, th...
# 9   (the movie from the guard is good, the movie f...
# 10  (the author next to the guard laughs, the auth...
# 11  (the movie that the guard likes is good, the m...
# 12  (the author that the guard likes laughs, the a...
# 13  (the movie the guard likes is good, the movie ...
# 14  (the author the guard likes laughs, the author...
# 15  (the movie the guard likes is good, the movie ...
# 16  (the author the guard likes laughs, the author...
# 17  (the movie that the guard likes is good, the m...
# 18  (the author that the guard likes laughs, the a...
# 19  (no movies that the guards like have ever been...
# 20  (no authors that the guards like have ever bee...
# 21  (the author knows many different foreign langu...
#
#                                             sample_k1
# 0   (the authors laugh and swim, the authors laugh...
# 1   (the author that likes the guards laughs, the ...
# 2   (the authors hurt themselves, the authors hurt...
# 3   (no movies will ever be seen, the movies will ...
# 4   (no authors will ever be popular, the authors ...
# 5             (the authors laugh, the authors laughs)
# 6   (the mechanics said the author laughs, the mec...
# 7   (the author that the guards like hurt himself,...
# 8   (the mechanics said the author hurt himself, t...
# 9   (the movie from the guards is good, the movie ...
# 10  (the author next to the guards laughs, the aut...
# 11  (the movies that the guard likes are good, the...
# 12  (the authors that the guard likes laugh, the a...
# 13  (the movies the guard likes are good, the movi...
# 14  (the authors the guard likes laugh, the author...
# 15  (the movie the guards like is good, the movie ...
# 16  (the author the guards like laughs, the author...
# 17  (the movie that the guards like is good, the m...
# 18  (the author that the guards like laughs, the a...
# 19  (no movies that the guards like will ever be s...
# 20  (no authors that the guards like will ever be ...
# 21  (the authors know many different foreign langu...

# %%
for i, row in eda_data.iterrows():
    print ("\n{}, {}, {}, {}".format(i, row.name_, row.keys_, row.n_item))
    print (row["sample_k0"])
    print (row["sample_k1"])
# Out:
# 0, vp_coord, ['sing_MS_MV_MV', 'plur_MS_MV_MV'], 420
# ('the author laughs and swims', 'the author laughs and swim')
# ('the authors laugh and swim', 'the authors laugh and swims')
#
# 1, subj_rel, ['sing_MS_EV_MV_sing_ES', 'sing_MS_EV_MV_plur_ES', 'plur_MS_EV_MV_sing_ES', 'plur_MS_EV_MV_plur_ES'], 2800
# ('the author that likes the guard laughs', 'the author that likes the guard laugh')
# ('the author that likes the guards laughs', 'the author that likes the guards laugh')
#
# 2, simple_reflexives, ['sing_MS_ANPHR', 'plur_MS_ANPHR'], 140
# ('the author hurt himself', 'the author hurt themselves')
# ('the authors hurt themselves', 'the authors hurt himself')
#
# 3, simple_npi_inanim, ['past', 'future'], 72
# ('no movies have ever been seen', 'the movies have ever been seen', 'most movies have ever been seen')
# ('no movies will ever be seen', 'the movies will ever be seen', 'most movies will ever be seen')
#
# 4, simple_npi_anim, ['past', 'future'], 60
# ('no authors have ever been popular', 'the authors have ever been popular', 'most authors have ever been popular')
# ('no authors will ever be popular', 'the authors will ever be popular', 'most authors will ever be popular')
#
# 5, simple_agrmt, ['sing_MS_MV', 'plur_MS_MV'], 70
# ('the author laughs', 'the author laugh')
# ('the authors laugh', 'the authors laughs')
#
# 6, sent_comp, ['sing_MS_MV_sing_BS', 'sing_MS_MV_plur_BS', 'plur_MS_MV_sing_BS', 'plur_MS_MV_plur_BS'], 420
# ('the mechanic said the author laughs', 'the mechanic said the author laugh')
# ('the mechanics said the author laughs', 'the mechanics said the author laugh')
#
# 7, reflexives_across, ['sing_MS_ANPHR_sing_ES_EV', 'sing_MS_ANPHR_plur_ES_EV', 'plur_MS_ANPHR_sing_ES_EV', 'plur_MS_ANPHR_plur_ES_EV'], 5600
# ('the author that the guard likes hurt himself', 'the author that the guard likes hurt themselves')
# ('the author that the guards like hurt himself', 'the author that the guards like hurt themselves')
#
# 8, reflexive_sent_comp, ['sing_MS_ANPHR_sing_BS', 'sing_MS_ANPHR_plur_BS', 'plur_MS_ANPHR_sing_BS', 'plur_MS_ANPHR_plur_BS'], 840
# ('the mechanic said the author hurt himself', 'the mechanic said the author hurt themselves')
# ('the mechanics said the author hurt himself', 'the mechanics said the author hurt themselves')
#
# 9, prep_inanim, ['sing_IS_IV_sing_ES', 'sing_IS_IV_plur_ES', 'plur_IS_IV_sing_ES', 'plur_IS_IV_plur_ES'], 1260
# ('the movie from the guard is good', 'the movie from the guard are good')
# ('the movie from the guards is good', 'the movie from the guards are good')
#
# 10, prep_anim, ['sing_MS_MV_sing_ES', 'sing_MS_MV_plur_ES', 'plur_MS_MV_sing_ES', 'plur_MS_MV_plur_ES'], 4200
# ('the author next to the guard laughs', 'the author next to the guard laugh')
# ('the author next to the guards laughs', 'the author next to the guards laugh')
#
# 11, obj_rel_within_inanim, ['sing_ES_EV_sing_IS_IV', 'sing_ES_EV_plur_IS_IV', 'plur_ES_EV_sing_IS_IV', 'plur_ES_EV_plur_IS_IV'], 2520
# ('the movie that the guard likes is good', 'the movie that the guard like is good')
# ('the movies that the guard likes are good', 'the movies that the guard like are good')
#
# 12, obj_rel_within_anim, ['sing_ES_EV_sing_MS_MV', 'sing_ES_EV_plur_MS_MV', 'plur_ES_EV_sing_MS_MV', 'plur_ES_EV_plur_MS_MV'], 2800
# ('the author that the guard likes laughs', 'the author that the guard like laughs')
# ('the authors that the guard likes laugh', 'the authors that the guard like laugh')
#
# 13, obj_rel_no_comp_within_inanim, ['sing_ES_EV_sing_IS_IV', 'sing_ES_EV_plur_IS_IV', 'plur_ES_EV_sing_IS_IV', 'plur_ES_EV_plur_IS_IV'], 2520
# ('the movie the guard likes is good', 'the movie the guard like is good')
# ('the movies the guard likes are good', 'the movies the guard like are good')
#
# 14, obj_rel_no_comp_within_anim, ['sing_ES_EV_sing_MS_MV', 'sing_ES_EV_plur_MS_MV', 'plur_ES_EV_sing_MS_MV', 'plur_ES_EV_plur_MS_MV'], 2800
# ('the author the guard likes laughs', 'the author the guard like laughs')
# ('the authors the guard likes laugh', 'the authors the guard like laugh')
#
# 15, obj_rel_no_comp_across_inanim, ['sing_IS_IV_sing_ES_EV', 'sing_IS_IV_plur_ES_EV', 'plur_IS_IV_sing_ES_EV', 'plur_IS_IV_plur_ES_EV'], 2520
# ('the movie the guard likes is good', 'the movie the guard likes are good')
# ('the movie the guards like is good', 'the movie the guards like are good')
#
# 16, obj_rel_no_comp_across_anim, ['sing_MS_MV_sing_ES_EV', 'sing_MS_MV_plur_ES_EV', 'plur_MS_MV_sing_ES_EV', 'plur_MS_MV_plur_ES_EV'], 2800
# ('the author the guard likes laughs', 'the author the guard likes laugh')
# ('the author the guards like laughs', 'the author the guards like laugh')
#
# 17, obj_rel_across_inanim, ['sing_IS_IV_sing_ES_EV', 'sing_IS_IV_plur_ES_EV', 'plur_IS_IV_sing_ES_EV', 'plur_IS_IV_plur_ES_EV'], 2520
# ('the movie that the guard likes is good', 'the movie that the guard likes are good')
# ('the movie that the guards like is good', 'the movie that the guards like are good')
#
# 18, obj_rel_across_anim, ['sing_MS_MV_sing_ES_EV', 'sing_MS_MV_plur_ES_EV', 'plur_MS_MV_sing_ES_EV', 'plur_MS_MV_plur_ES_EV'], 2800
# ('the author that the guard likes laughs', 'the author that the guard likes laugh')
# ('the author that the guards like laughs', 'the author that the guards like laugh')
#
# 19, npi_across_inanim, ['past', 'future'], 2880
# ('no movies that the guards like have ever been seen', 'the movies that no guards like have ever been seen', 'most movies that the guards like have ever been seen')
# ('no movies that the guards like will ever be seen', 'the movies that no guards like will ever be seen', 'most movies that the guards like will ever be seen')
#
# 20, npi_across_anim, ['past', 'future'], 2400
# ('no authors that the guards like have ever been popular', 'the authors that no guards like have ever been popular', 'most authors that the guards like have ever been popular')
# ('no authors that the guards like will ever be popular', 'the authors that no guards like will ever be popular', 'most authors that the guards like will ever be popular')
#
# 21, long_vp_coord, ['sing_MS_LMV_LMV', 'plur_MS_LMV_LMV'], 200
# ('the author knows many different foreign languages and likes to watch television shows', 'the author knows many different foreign languages and like to watch television shows')
# ('the authors know many different foreign languages and like to watch television shows', 'the authors know many different foreign languages and likes to watch television shows')

# %%
def preprocess_syneval_data(syneval_data, max_per_category=100):
    correct_sents_data = {}
    for name in syneval_data:
        D = {}
        for key in syneval_data[name]:
            allsents = syneval_data[name][key]
            corr_sents = [item[0] for item in allsents]
            D[key] = corr_sents[:min(len(corr_sents), max_per_category)]
        correct_sents_data[name] = D
    return correct_sents_data

correct_sents_data = preprocess_syneval_data(syneval_data)
del syneval_data

# %%
correct_sents_data["npi_across_anim"]["past"][0:10]
# Out:
# ['no authors that the guards like have ever been popular',
#  'no authors that the guards like have ever been famous',
#  'no authors that the guards like have ever had children',
#  'no authors that the guards admire have ever been popular',
#  'no authors that the guards admire have ever been famous',
#  'no authors that the guards admire have ever had children',
#  'no authors that the guards hate have ever been popular',
#  'no authors that the guards hate have ever been famous',
#  'no authors that the guards hate have ever had children',
#  'no authors that the guards love have ever been popular']

# %% [markdown]
# ## Examine the embedding diff vectors

# %%
@timed_func
def name2vecs(correct_sents_data, name):
    data = correct_sents_data[name]
    if len(data.keys()) > 2:
        print ("{} contains more than 2 categories. I'm taking only the first two".format(name))
    k1, k2 = list(data.keys())[:2]
    diffs = []
    for s1, s2 in zip(data[k1], data[k2]):
        diffs.append(evaluate_contextual_diff([s1, s2]))
    return torch.stack(diffs)  # (N, 768) tensor

names = ["vp_coord", "subj_rel", "simple_reflexives", "sent_comp", "simple_agrmt", 
            "reflexives_across"]
collections = [name2vecs(correct_sents_data, name) for name in names]
# Out:
# name2vecs done in 14.05 seconds.
# subj_rel contains more than 2 categories. I'm taking only the first two
# name2vecs done in 25.52 seconds.
# name2vecs done in 27.17 seconds.
# sent_comp contains more than 2 categories. I'm taking only the first two
# name2vecs done in 32.57 seconds.
# name2vecs done in 26.65 seconds.
# reflexives_across contains more than 2 categories. I'm taking only the first two
# name2vecs done in 56.01 seconds.

# %%
colors = dict(mcolors.TABLEAU_COLORS, **mcolors.CSS4_COLORS)
def make_plot(all_vecs, names):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111)
    
    palette = [
        colors["tab:blue"], colors["tab:orange"], colors["tab:green"], colors["tab:red"], colors["tab:purple"], 
        colors["tab:brown"], colors["tab:pink"], colors["tab:gray"], colors["tab:olive"], colors["tab:cyan"]
    ]
    assert len(palette) >= len(names), "Palette only has {} colors, but requested {}".format(len(palette), len(names))
    
    pca = PCA(n_components=2)
    all_vecs_combined = torch.cat(all_vecs, dim=0)
    pca.fit(all_vecs_combined.detach().numpy())
    for i, vecs in enumerate(all_vecs):
        z = pca.transform(vecs.detach().numpy())  # (n_pt, 2)
        ax.plot(z[:, 0], z[:, 1], "o", c=palette[i], markersize=3, label=names[i])
        
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    plt.legend()
    plt.title('2-D PCA of the difference in context')
    plt.show()

make_plot(collections, names)

# %% [markdown]
# ## Interpretation?
# 1. BERT is indeed some sort of "LM as inherent disentangled multitask encoder".
# 2. Looks like "subj_rel", "sent_comp" and "reflexives_across" form a large cluster. These three groups happen to be those with >=3 keys (which I take only the first two). The remaining three categories contain only 2 keys.
# 3. Marvin & Linzen sentence pairs do not have enough diversity. Probably look at BLiMP data in the next notebook.
